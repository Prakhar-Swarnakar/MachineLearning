# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
csv_path = "C:\\Projects\\Learning Files\\jupiter Code\\MachineLearning\\Home Data Simple Linear Regression.csv"

# %%
df = pd.read_csv(csv_path)
df.values.tolist()
# Out:
# [[2600, 550000],
#  [3600, 680000],
#  [4000, 725000],
#  [3200, 610000],
#  [3000, 565000]]

# %%
# %matplotlib inline
plt.scatter(df.Area,df.Price,color="red",marker="+")

# %%
plt.xlabel('area(sq feet)')
plt.ylabel("price in US$")
plt.scatter(df.Area,df.Price,color="red")

# %%
reg = linear_model.LinearRegression()
reg.fit(df[["Area"]],df.Price)
# Out:
# LinearRegression()

# %%
reg.predict([[3300]])
# Out:
# C:\Users\H532843\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
reg.coef_   # m in y = mx+c

# %%
reg.intercept_ # c in y = mx+c
